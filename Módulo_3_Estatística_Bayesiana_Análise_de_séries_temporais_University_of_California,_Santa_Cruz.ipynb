# %% [markdown]
# <a href="https://colab.research.google.com/github/emanuel379/Series-Temporais-e-Aprendizado-Dinamico/blob/main/M%C3%B3dulo_3_Estat%C3%ADstica_Bayesiana_An%C3%A1lise_de_s%C3%A9ries_temporais_University_of_California%2C_Santa_Cruz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
install.packages("dlm")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %% [markdown]
# Considere o seguinte código R:

# %%
#######################
##### DLM package #####
#######################

library(dlm)
k=4
T=length(LakeHuron)-k # We take the first
                      # 94 observations only as our data
index=seq(1875, 1972, length.out = length(LakeHuron))
index_filt=index[1:T]

model=dlmModPoly(order=1,dV=1,dW=1,m0=570,C0=1e4)
results_filtered_dlm=dlmFilter(LakeHuron[1:T],model)
results_smoothed_dlm=dlmSmooth(results_filtered_dlm)

plot(index_filt, LakeHuron[1:T], ylab = "level",
     main = "Lake Huron Level",
     type='l', xlab="time",lty=3,ylim=c(575,583))
points(index_filt,LakeHuron[1:T],pch=20)
lines(index_filt,results_filtered_dlm$m[-1],col='red',lwd=2)
lines(index_filt,results_smoothed_dlm$s[-1],col='blue',lwd=2)
legend(1880,577, legend=c("filtered", "smoothed"),
       col=c("red", "blue"), lty=1, cex=0.8)
# Out:
# Plot with title “Lake Huron Level”

# %% [markdown]
# Observe que o senhor precisará instalar o pacote dlm no R, caso não o tenha instalado, para executar o código acima. Depois de instalar o pacote e executar o código acima, o senhor será solicitado a alterar algumas das especificações do modelo, carregar alguns gráficos e responder a algumas perguntas. Em particular, será solicitado ao senhor que:
#
# Modificar o código acima para alterar a variância da distribuição anterior de
# 𝐶0 = 10^4 para 𝐶0 =10. Trace e carregue os traços de 𝐸(𝜃𝑡∣𝐷𝑡) (média da distribuição filtrada) e 𝐸(𝜃𝑡∣𝐷𝑇) para 𝑇 ≥ 𝑡 e todos os 𝑡 = 1:𝑇 (média da distribuição suavizada). Esses novos resultados são diferentes dos resultados do modelo com 𝐶0 = 10^4?

# %%
#######################
##### DLM package #####
#######################

library(dlm)
k=4
T=length(LakeHuron)-k # We take the first
                      # 94 observations only as our data
index=seq(1875, 1972, length.out = length(LakeHuron))
index_filt=index[1:T]

model=dlmModPoly(order=1,dV=1,dW=1,m0=570,C0=10)
results_filtered_dlm=dlmFilter(LakeHuron[1:T],model)
results_smoothed_dlm=dlmSmooth(results_filtered_dlm)

plot(index_filt, LakeHuron[1:T], ylab = "level",
     main = "Lake Huron Level",
     type='l', xlab="time",lty=3,ylim=c(575,583))
points(index_filt,LakeHuron[1:T],pch=20)
lines(index_filt,results_filtered_dlm$m[-1],col='red',lwd=2)
lines(index_filt,results_smoothed_dlm$s[-1],col='blue',lwd=2)
legend(1880,577, legend=c("filtered", "smoothed"),
       col=c("red", "blue"), lty=1, cex=0.8)
# Out:
# Plot with title “Lake Huron Level”

# %% [markdown]
# Com excessão do período inicial, é possível observar que os resultados obtidos não apresentam diferenças na qualidade dos ajustes.

# %% [markdown]
# Mantenha a variância da distribuição anterior em 𝐶0 = 10^4. Agora, altere a variação da evolução de 𝑊 = 1 para 𝑊 = 0.01. Trace e carregue as novas médias dos resultados filtrados e suavizados. Elas são diferentes dos resultados quando a variação da evolução é 𝑊 = 1?

# %%
#######################
##### DLM package #####
#######################

library(dlm)
k=4
T=length(LakeHuron)-k # We take the first
                      # 94 observations only as our data
index=seq(1875, 1972, length.out = length(LakeHuron))
index_filt=index[1:T]

model=dlmModPoly(order=1,dV=1,dW=0.01,m0=570,C0=1e4)
results_filtered_dlm=dlmFilter(LakeHuron[1:T],model)
results_smoothed_dlm=dlmSmooth(results_filtered_dlm)

plot(index_filt, LakeHuron[1:T], ylab = "level",
     main = "Lake Huron Level",
     type='l', xlab="time",lty=3,ylim=c(575,583))
points(index_filt,LakeHuron[1:T],pch=20)
lines(index_filt,results_filtered_dlm$m[-1],col='red',lwd=2)
lines(index_filt,results_smoothed_dlm$s[-1],col='blue',lwd=2)
legend(1880,577, legend=c("filtered", "smoothed"),
       col=c("red", "blue"), lty=1, cex=0.8)
# Out:
# Plot with title “Lake Huron Level”

# %% [markdown]
# Sim, as curvas para 𝑊 = 0.01 são muito mais suaves e interpretáveis que para 𝑊 = 1, sendo possível observar um comportamento temporal mais claro, embora o ajuste esteja mais distante dos valores reais observados.
